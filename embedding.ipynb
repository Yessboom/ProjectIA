# %%
# %pip install sentence-transformers redis
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (5.2.0)
# Requirement already satisfied: redis in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (7.1.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\tangu\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
import csv
import io
import os 
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from datetime import datetime, timedelta


EVENTBRITE_API_KEY = os.getenv("EVENTBRITE_PRIVATE_TOKEN")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
def get_embedding(text: str) -> np.ndarray:
    """Get embedding vector for text using sentence-transformers.
    
    Args:
        text: Text to embed
        
    Returns:
        np.ndarray: Embedding vector
    """
    return embedding_model.encode(text)

# %%
# In-memory cache with TTL using a dict
class CacheWithTTL:
    def __init__(self):
        self.cache = {}
        self.expiry = {}
    
    def get(self, key):
        if key in self.cache:
            if datetime.now() < self.expiry.get(key, datetime.now()):
                return self.cache[key]
            else:
                del self.cache[key]
                del self.expiry[key]
        return None
    
    def set(self, key, value, ttl_seconds):
        self.cache[key] = value
        self.expiry[key] = datetime.now() + timedelta(seconds=ttl_seconds)

# Initialize cache
local_cache = CacheWithTTL()

def fetch_events_to_cache(force_refresh: bool = False, cache_ttl: int = 36000) -> list:
    """Fetch events from API and cache locally.
    
    Args:
        force_refresh: If True, bypass cache and fetch fresh data
        cache_ttl: Cache time-to-live in seconds (default: 10 hours)
    
    Returns:
        list: List of event dictionaries
    """
    cache_key = 'eventbrite:events:all'
    
    # Try to get from cache first
    if not force_refresh:
        cached_data = local_cache.get(cache_key)
        if cached_data:
            print("Using cached events from local memory")
            return cached_data
    
    # Fetch fresh data from API
    #print("Fetching fresh events from API")
    IdList = ['295288568', '271238193', '278600043', '279838893', '290674563', 
          '294827703', '282508363','295080090', '244133673','277705833', 
          '294348103', '295110583', '275248603', '287778843', '286500573',
           '279399083','279399743', '279400403', '295198507','275935733',
            '292626743', '283994593', '285424813', '251187193', '295487905',
             '294728683', '291984493', '295103082','287935003', '295184668', 
             '295258183', '286548243','295173004', '295311294', '295284070']
    
    all_events = []
    
    for venue_id in IdList:
        url = f'https://www.eventbriteapi.com/v3/venues/{venue_id}/events/'
        headers = {'Authorization': f'Bearer {EVENTBRITE_API_KEY}'}
        params = {'status': 'live', 'order_by': 'start_asc'}
        
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            events = response.json().get('events', [])
            for event in events:
                event_name = event['name']['text']
                event_desc = event.get('description', {}).get('text', '')[:500] if event.get('description') else ""
                
                all_events.append({
                    "name": event_name,
                    "date": event['start']['local'],
                    "url": event['url'],
                    "description": event_desc.replace('\n', ' '),
                    "full_text": f"{event_name}. {event_desc}"
                })
    
    # Cache locally
    local_cache.set(cache_key, all_events, cache_ttl)
    print(f"Cached {len(all_events)} events in local memory")
    
    return all_events
# Out:
# Cached 20 events in local memory
# name,date,url,description
# Jamii Padel x Tour & Taxis Beginner Friendly Tournament,2025-12-14T12:00:00,https://www.eventbrite.be/e/jamii-padel-x-tour-taxis-beginner-friendly-tournament-tickets-1974363890545,"Join us for a fun and beginner-friendly Padel tournament at Tour & Taxis, perfect for connecting with the Jamii community!"
# Mathematics in motion: from bears to beyond,2026-01-07T19:00:00,https://www.eventbrite.com/e/mathematics-in-motion-from-bears-to-beyond-tickets-1977698196544,"Mathematics is the quiet foundation beneath everything we see and build, shaping even the way we understand the world..."
# The Cost of Growth. Documentary Screening & Discussion with Anuna De Wever,2025-12-15T18:30:00,https://www.eventbrite.be/e/the-cost-of-growth-documentary-screening-discussion-with-anuna-de-wever-tickets-1974251689950,"Reserve your ticket now to join us for a special screening night of The Cost of Growth, followed by a live discussion with co-producer Anuna"
# Le Trio Joubran,2026-03-22T20:00:00,https://www.eventbrite.com/e/le-trio-joubran-tickets-1969974478696,The Palestinian brothers Le Trio Joubran will perform in Brussels on March 22.
# KinArmat Talks with CEO Isabelle De Walsche,2025-12-15T18:30:00,https://www.eventbrite.be/e/kinarmat-talks-with-ceo-isabelle-de-walsche-tickets-1968487679640,"At the KinArmat Talks, we delve beyond titles to engage in honest conversations about leadership, ambition, and impact."
#
# Using cached events from local memory
# name,date,url,description
# Jamii Padel x Tour & Taxis Beginner Friendly Tournament,2025-12-14T12:00:00,https://www.eventbrite.be/e/jamii-padel-x-tour-taxis-beginner-friendly-tournament-tickets-1974363890545,"Join us for a fun and beginner-friendly Padel tournament at Tour & Taxis, perfect for connecting with the Jamii community!"
# Crossing by More Love Ensemble,2025-12-15T19:00:00,https://www.eventbrite.com/e/crossing-by-more-love-ensemble-tickets-1828894575909,"More Love Ensemble brings Crossing to Brussels, an extraordinary musical journey inspired by the treasures of Croatian classical music."
# "Soirée Stand Up ""Sac à Malice"" Pompette",2026-01-07T20:30:00,https://www.eventbrite.fr/e/soiree-stand-up-sac-a-malice-pompette-tickets-1510666507189,6 artistes incroyable vous feront rire et sourire dans la joie et la fête !
# "Soirée Stand Up ""Sac à Malice"" Pompette",2026-01-14T20:30:00,https://www.eventbrite.fr/e/soiree-stand-up-sac-a-malice-pompette-tickets-1510667680699,6 artistes incroyable vous feront rire et sourire dans la joie et la fête !
# BRUSSELS x Old School Vibes,2025-12-19T23:00:00,https://www.eventbrite.de/e/brussels-x-old-school-vibes-tickets-1431579726499,BELGIUM - WE ARE BACK! ++ Old School Vibes - Only Hip Hop & RnB // 90s & 2000s ++
# MURUBUTU live @ Pilar,2026-01-31T19:30:00,https://www.eventbrite.be/e/murubutu-live-pilar-tickets-1973110907840,"Murubutu live at Pilar, Brussels"
# PATAGARRI LIVE @PILAR,2026-03-07T19:30:00,https://www.eventbrite.be/e/patagarri-live-pilar-tickets-1977613884364,"I PATAGARRI ignite the stage with an explosive blend of gypsy jazz, swing, and blues — pure energy and musical freedom."
# The Cost of Growth. Documentary Screening & Discussion with Anuna De Wever,2025-12-15T18:30:00,https://www.eventbrite.be/e/the-cost-of-growth-documentary-screening-discussion-with-anuna-de-wever-tickets-1974251689950,"Reserve your ticket now to join us for a special screening night of The Cost of Growth, followed by a live discussion with co-producer Anuna"
# Afrobeats N Brunch  BRUSSELS - Wonderland - Sat 20th Dec,2025-12-20T16:00:00,https://www.eventbrite.ch/e/afrobeats-n-brunch-brussels-wonderland-sat-20th-dec-tickets-1972529626211,"Global vibes, family energy! ABNB Afro Wonderland hits Brussels Sat 20th Dec with international DJs, hosts & festive Afrobeats."
# """ Au-delà de la douleur"" Avant-première | Ciné talk",2025-12-20T15:00:00,https://www.eventbrite.be/e/au-dela-de-la-douleur-avant-premiere-cine-talk-tickets-1948506207519,L’ASBL Kalifa vous invite à un après-midi fort en émotions et en échanges autour de la drépanocytose.
# SELDA BAĞCAN LIVE,2026-02-15T20:00:00,https://www.eventbrite.com/e/selda-bagcan-live-tickets-1795327004399,Selda Bağcan 15 şubat Novum sahnesinde Brüksel'de sevenleri ile buluşuyor / Selda Bagcan meets her fans at Novum Brussels!
# Le Trio Joubran,2026-03-22T20:00:00,https://www.eventbrite.com/e/le-trio-joubran-tickets-1969974478696,The Palestinian brothers Le Trio Joubran will perform in Brussels on March 22.
# POP X,2026-01-17T21:00:00,https://www.eventbrite.be/e/pop-x-tickets-1972541632121,"POP X arrives in Brussels with a LIVE  TOUR IN EUROPE, ready to transform Pilar Bruxelles into a wild, immersive and liberating  experience."
# "WE LOVE 80s, 90s, 00s / ENTRÉE GRATUITE <22h30 / Single Party / Acte 3",2025-12-27T21:00:00,https://www.eventbrite.be/e/billets-we-love-80s-90s-00s-entree-gratuite-22h30-single-party-acte-3-1974243060138,COEUR COEUR & GENERATION30+ vous fixent rendez-vous à L’Acte 3 Event Hall pour LA PLUS GRANDE SOIREE   spéciale pour célibataires

# %%
def get_eventBrite_events_csv(category_filter: str = None, similarity_threshold: float = 0.15, force_refresh: bool = False) -> str:
    """Get upcoming events from EventBrite as CSV, optionally filtered by category."""
    
    # Get events from local cache (or fetch if not cached)
    all_events = fetch_events_to_cache(force_refresh)
    
    filtered_events = []
    
    # Get category embedding if filter is specified
    category_embedding = None
    if category_filter:
        category_embedding = get_embedding(category_filter).reshape(1, -1)
    
    for event in all_events:
        # If category filter is set, check similarity
        include_event = True
        similarity_score = None
        
        if category_filter and category_embedding is not None:
            event_embedding = get_embedding(event['full_text']).reshape(1, -1)
            similarity_score = cosine_similarity(category_embedding, event_embedding)[0][0]
            include_event = similarity_score >= similarity_threshold
        
        if include_event:
            filtered_events.append({
                "name": event['name'],
                "date": event['date'],
                "url": event['url'],
                "description": event['description'],
                "similarity": similarity_score
            })
    
    # Build CSV
    output = io.StringIO()
    writer = csv.writer(output)
    writer.writerow(["name", "date", "url", "description"])
    
    for event in filtered_events:
        writer.writerow([event['name'], event['date'], event['url'], event['description']])
    
    return output.getvalue()

# %%
print(get_eventBrite_events_csv(category_filter="sport"))
print("=========================")
print(get_eventBrite_events_csv(category_filter="music"))
print("------------------------")
print(get_eventBrite_events_csv(category_filter="tech events"))
# Out:
# Using cached events from local memory
# name,date,url,description
# Jamii Padel x Tour & Taxis Beginner Friendly Tournament,2025-12-14T12:00:00,https://www.eventbrite.be/e/jamii-padel-x-tour-taxis-beginner-friendly-tournament-tickets-1974363890545,"Join us for a fun and beginner-friendly Padel tournament at Tour & Taxis, perfect for connecting with the Jamii community!"
# Mathematics in motion: from bears to beyond,2026-01-07T19:00:00,https://www.eventbrite.com/e/mathematics-in-motion-from-bears-to-beyond-tickets-1977698196544,"Mathematics is the quiet foundation beneath everything we see and build, shaping even the way we understand the world..."
# MURUBUTU live @ Pilar,2026-01-31T19:30:00,https://www.eventbrite.be/e/murubutu-live-pilar-tickets-1973110907840,"Murubutu live at Pilar, Brussels"
# PATAGARRI LIVE @PILAR,2026-03-07T19:30:00,https://www.eventbrite.be/e/patagarri-live-pilar-tickets-1977613884364,"I PATAGARRI ignite the stage with an explosive blend of gypsy jazz, swing, and blues — pure energy and musical freedom."
# The Cost of Growth. Documentary Screening & Discussion with Anuna De Wever,2025-12-15T18:30:00,https://www.eventbrite.be/e/the-cost-of-growth-documentary-screening-discussion-with-anuna-de-wever-tickets-1974251689950,"Reserve your ticket now to join us for a special screening night of The Cost of Growth, followed by a live discussion with co-producer Anuna"
# SELDA BAĞCAN LIVE,2026-02-15T20:00:00,https://www.eventbrite.com/e/selda-bagcan-live-tickets-1795327004399,Selda Bağcan 15 şubat Novum sahnesinde Brüksel'de sevenleri ile buluşuyor / Selda Bagcan meets her fans at Novum Brussels!
# KinArmat Talks with CEO Isabelle De Walsche,2025-12-15T18:30:00,https://www.eventbrite.be/e/kinarmat-talks-with-ceo-isabelle-de-walsche-tickets-1968487679640,"At the KinArmat Talks, we delve beyond titles to engage in honest conversations about leadership, ambition, and impact."
#
# =========================
# Using cached events from local memory
# name,date,url,description
# Jamii Padel x Tour & Taxis Beginner Friendly Tournament,2025-12-14T12:00:00,https://www.eventbrite.be/e/jamii-padel-x-tour-taxis-beginner-friendly-tournament-tickets-1974363890545,"Join us for a fun and beginner-friendly Padel tournament at Tour & Taxis, perfect for connecting with the Jamii community!"
# Crossing by More Love Ensemble,2025-12-15T19:00:00,https://www.eventbrite.com/e/crossing-by-more-love-ensemble-tickets-1828894575909,"More Love Ensemble brings Crossing to Brussels, an extraordinary musical journey inspired by the treasures of Croatian classical music."
# Mathematics in motion: from bears to beyond,2026-01-07T19:00:00,https://www.eventbrite.com/e/mathematics-in-motion-from-bears-to-beyond-tickets-1977698196544,"Mathematics is the quiet foundation beneath everything we see and build, shaping even the way we understand the world..."
# "Soirée Stand Up ""Sac à Malice"" Pompette",2026-01-07T20:30:00,https://www.eventbrite.fr/e/soiree-stand-up-sac-a-malice-pompette-tickets-1510666507189,6 artistes incroyable vous feront rire et sourire dans la joie et la fête !
