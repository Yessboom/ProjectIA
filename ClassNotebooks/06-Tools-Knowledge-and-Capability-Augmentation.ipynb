# %% [markdown]
# # LangChain Tools: Knowledge and Capability Augmentation
#
# - Author: Martin Fockedey
#
# ## Introduction
#
# Large Language Models (LLMs) have remarkable capabilities, but they also have fundamental limitations:
# - **Knowledge cutoff**: Training data ends at a specific date
# - **No real-time information**: Cannot access current events, live data, or dynamic content
# - **Mathematical limitations**: Struggle with precise calculations
# - **No external interactions**: Cannot query databases, call APIs, or browse the web
#
# **LangChain Tools** solve these limitations by allowing LLMs to:
# 1. **Augment knowledge**: Access external information sources (web search, databases, APIs)
# 2. **Augment capabilities**: Perform precise operations (calculations, data processing, custom logic)
#
# In this notebook, we'll explore both types of augmentation with practical examples using Mistral AI.

# %% [markdown]
# ## Environment Setup
#
# Set up the environment.
#
# [Note]
# - You'll need a Mistral AI API key (see your Teams group channel).
# - For web search examples, you'll also need a Tavily API key (free tier available at https://tavily.com)
# - Store your API keys in a `.env` file as `MISTRAL_API_KEY` and `TAVILY_API_KEY`.

# %%
# Install required packages 
# !pip install mistralai python-dotenv requests
# Out:
# Collecting mistralai
#   Obtaining dependency information for mistralai from https://files.pythonhosted.org/packages/fe/76/4ce12563aea5a76016f8643eff30ab731e6656c845e9e4d090ef10c7b925/mistralai-1.9.11-py3-none-any.whl.metadata
#   Downloading mistralai-1.9.11-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: python-dotenv in c:\users\ziani\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: requests in c:\users\ziani\anaconda3\lib\site-packages (2.31.0)
# Collecting eval-type-backport>=0.2.0 (from mistralai)
#   Obtaining dependency information for eval-type-backport>=0.2.0 from https://files.pythonhosted.org/packages/19/d8/2a1c638d9e0aa7e269269a1a1bf423ddd94267f1a01bbe3ad03432b67dd4/eval_type_backport-0.3.0-py3-none-any.whl.metadata
#   Downloading eval_type_backport-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\ziani\anaconda3\lib\site-packages (from mistralai) (0.28.1)
# Collecting invoke<3.0.0,>=2.2.0 (from mistralai)
#   Obtaining dependency information for invoke<3.0.0,>=2.2.0 from https://files.pythonhosted.org/packages/32/4b/b99e37f88336009971405cbb7630610322ed6fbfa31e1d7ab3fbf3049a2d/invoke-2.2.1-py3-none-any.whl.metadata
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic>=2.10.3 in c:\users\ziani\anaconda3\lib\site-packages (from mistralai) (2.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ziani\anaconda3\lib\site-packages (from mistralai) (2.8.2)
# Collecting pyyaml<7.0.0,>=6.0.2 (from mistralai)
#   Obtaining dependency information for pyyaml<7.0.0,>=6.0.2 from https://files.pythonhosted.org/packages/da/e3/ea007450a105ae919a72393cb06f122f288ef60bba2dc64b26e2646fa315/pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ziani\anaconda3\lib\site-packages (from mistralai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ziani\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ziani\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ziani\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ziani\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: anyio in c:\users\ziani\anaconda3\lib\site-packages (from httpx>=0.28.1->mistralai) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ziani\anaconda3\lib\site-packages (from httpx>=0.28.1->mistralai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ziani\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->mistralai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ziani\anaconda3\lib\site-packages (from pydantic>=2.10.3->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\ziani\anaconda3\lib\site-packages (from pydantic>=2.10.3->mistralai) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\ziani\anaconda3\lib\site-packages (from pydantic>=2.10.3->mistralai) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\ziani\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ziani\anaconda3\lib\site-packages (from anyio->httpx>=0.28.1->mistralai) (1.2.0)
# Downloading mistralai-1.9.11-py3-none-any.whl (442 kB)
#    ---------------------------------------- 0.0/442.8 kB ? eta -:--:--
#     --------------------------------------- 10.2/442.8 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/442.8 kB 660.6 kB/s eta 0:00:01
#    ----------------- ---------------------- 194.6/442.8 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 442.8/442.8 kB 3.1 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.0-py3-none-any.whl (6.1 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
#    ---------------------------------------- 0.0/160.3 kB ? eta -:--:--
#    ---------------------------------------- 160.3/160.3 kB ? eta 0:00:00
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#    ---------------------------------------- 0.0/158.8 kB ? eta -:--:--
#    ---------------------------------------- 158.8/158.8 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: pyyaml, invoke, eval-type-backport, mistralai
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed eval-type-backport-0.3.0 invoke-2.2.1 mistralai-1.9.11 pyyaml-6.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires PyYAML==6.0.1, but you have pyyaml 6.0.3 which is incompatible.
# datasets 2.12.0 requires huggingface-hub<1.0.0,>=0.11.0, but you have huggingface-hub 1.0.1 which is incompatible.
# transformers 4.32.1 requires huggingface-hub<1.0,>=0.15.1, but you have huggingface-hub 1.0.1 which is incompatible.
# transformers 4.32.1 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.22.1 which is incompatible.

# %%
# Environment setup using official mistralai client (no LangChain)
import os, json, inspect
from dotenv import load_dotenv
from typing import Callable, List

from mistralai import Mistral, UserMessage, ToolMessage

load_dotenv(override=True)

API_KEY = os.getenv("MISTRAL_API_KEY")
if not API_KEY:
    print("Warning: MISTRAL_API_KEY is not set.")

MODEL_NAME = os.getenv("MISTRAL_MODEL", "mistral-small")
TEMPERATURE = float(os.getenv("MISTRAL_TEMPERATURE", "0.0"))
client = Mistral(api_key=API_KEY)

print(f"Environment loaded! Using model: {MODEL_NAME}")

def build_tool_spec(func: Callable):
    """Build a tool spec dict from a plain python function.
    Assumes all parameters are strings unless type annotation gives something else.
    """
    sig = inspect.signature(func)
    props = {}
    required = []
    for name, param in sig.parameters.items():
        ann = param.annotation
        ann_type = "string"
        if ann in (int, float):
            ann_type = "number"
        props[name] = {"type": ann_type}
        if param.default is inspect._empty:
            required.append(name)
    return {
        "type": "function",
        "function": {
            "name": func.__name__,
            "description": (func.__doc__ or "").strip()[:800],
            "parameters": {
                "type": "object",
                "properties": props,
                "required": required
            }
        }
    }

def run_tool_chat(user_content: str, funcs: List[Callable], model: str = MODEL_NAME, temperature: float = TEMPERATURE):
    """Send a user message, handle any tool calls, return final answer string."""
    messages = [UserMessage(role="user", content=user_content)]
    tool_specs = [build_tool_spec(f) for f in funcs]
    first = client.chat.complete(model=model, messages=messages, tools=tool_specs, temperature=temperature)
    msg = first.choices[0].message
    tool_calls = msg.tool_calls or []
    if not tool_calls:
        return msg.content
    messages.append(msg)
    for tc in tool_calls:
        # Parse args and execute matching function
        args = json.loads(tc.function.arguments)
        fn = next((f for f in funcs if f.__name__ == tc.function.name), None)
        if fn is None:
            result = f"Error: function {tc.function.name} not implemented"
        else:
            try:
                result = fn(**args)
            except Exception as e:
                result = f"Error executing {tc.function.name}: {e}".strip()
        print(f"Tool {tc.function.name}({args}) -> {str(result)[:160]}")
        messages.append(ToolMessage(role="tool", content=str(result), name=tc.function.name, tool_call_id=tc.id))
    final = client.chat.complete(model=model, messages=messages, temperature=temperature)
    return final.choices[0].message.content
# Out:
# Environment loaded! Using model: mistral-small

# %% [markdown]
# ## Part 1: Capability Augmentation
#
# Capability augmentation gives LLMs the ability to perform operations they cannot do natively, such as precise calculations or string manipulation.
#
# ### Example 1.1: Calculator Tool
#
# LLMs are notoriously bad at arithmetic. Let's create a calculator tool to fix this.

# %%
# First, let's see the LLM fail at math
print("=== Without Calculator Tool ===")
response = client.chat.complete(model=MODEL_NAME, messages=[UserMessage(role="user", content="What is 1247256 * 548936 / 452661?")], temperature=TEMPERATURE)
print(response.choices[0].message.content)
print()
# Out:
# === Without Calculator Tool ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# ### Understanding the Problem
#
# First, I need to understand what's being asked. The problem is:
#
# **What is 1247256 × 548936 / 452661?**
#
# This is a combination of multiplication and division. To break it down:
# 1. Multiply two large numbers: 1,247,256 and 548,936.
# 2. Divide the result from step 1 by another large number: 452,661.
#
# ### Step 1: Breaking Down the Multiplication
#
# Multiplying two large numbers like 1,247,256 and 548,936 seems daunting. I recall the **distributive property of multiplication over addition**, which allows breaking down the problem into simpler parts.
#
# #### Using the FOIL Method (or Binomial Expansion)
#
# I think of the numbers in terms of their components:
# - **First Number (A)**: 1,247,256
# - **Second Number (B)**: 548,936
#
# I can express B as (500,000 + 40,000 + 8,000 + 900 + 30 + 6).
#
# Now, I can multiply A by each component of B and then add the results.
#
# 1. **Multiply A by 500,000**:
#    \[ 1,247,256 × 500,000 = 1,247,256 × 5 × 10^5 = 6,236,280 × 10^5 = 623,628,000,000\]
#
# 2. **Multiply A by 40,000**:
#    \[ 1,247,256 × 40,000 = 1,247,256 × 4 × 10^4 = 4,989,024 × 10^4 = 49,890,240,000\]
#
# 3. **Multiply A by 8,000**:
#    \[ 1,247,256 × 8,000 = 1,247,256 × 8 × 10^3 = 9,978,048 × 10^3 = 9,978,048,000\]
#
# 4. **Multiply A by 900**:
#    \[ 1,247,256 × 900 = 1,247,256 × 9 × 10^2 = 11,225,304 × 10^2 = 1,122,530,400\]
#
# 5. **Multiply A by 30**:
#    \[ 1,247,256 × 30 = 1,247,256 × 3 × 10 = 3,741,768 × 10 = 37,417,680\]
#
# 6. **Multiply A by 6**:
#    \[ 1,247,256 × 6 = 7,483,536\]
#
# Now, add all these partial results together:
# 1. Start with the largest term: 623,628,000,000
# 2. Add the next term: 623,628,000,000 + 49,890,240,000 = 673,518,240,000
# 3. Add the next term: 673,518,240,000 + 9,978,048,000 = 683,496,288,000
# 4. Add the next term: 683,496,288,000 + 1,122,530,400 = 684,618,818,400
# 5. Add the next term: 684,618,818,400 + 37,417,680 = 684,656,236,080
# 6. Finally, add the last term: 684,656,236,080 + 7,483,536 = 684,663,719,616
#
# So, the product of 1,247,256 × 548,936 is **684,663,719,616**.
#
# ### Verification of Multiplication
#
# To ensure accuracy, I recall the **long multiplication** method. However, given the size of the numbers, it's complex, but I can try a simplified version.
#
# Let's break it down using the **Karatsuba algorithm**, which reduces the number of multiplications.
#
# #### Karatsuba Algorithm
#
# The idea is to split the numbers into two parts:
# - A = 1,247,256 = 1,247 × 10^3 + 256
# - B = 548,936 = 548 × 10^3 + 936
#
# Now, according to Karatsuba:
# \[ A × B = (A1 × 10^3 + A0) × (B1 × 10^3 + B0) = A1 × B1 × 10^6 + (A1 × B0 + A0 × B1) × 10^3 + A0 × B0 \]
#
# Where:
# - A1 = 1,247
# - A0 = 256
# - B1 = 548
# - B0 = 936
#
# Now, compute the necessary products:
# 1. **A1 × B1**: 1,247 × 548
#    - Break it down: (1,000 + 200 + 40 + 7) × 548
#    - 1,000 × 548 = 548,000
#    - 200 × 548 = 109,600
#    - 40 × 548 = 21,920
#    - 7 × 548 = 3,836
#    - Sum: 548,000 + 109,600 = 657,600
#    - 657,600 + 21,920 = 679,520
#    - 679,520 + 3,836 = 683,356
#
# 2. **A0 × B0**: 256 × 936
#    - Break it down: 256 × (1,000 - 64) = 256,000 - 16,384 = 239,616
#
# 3. **A1 × B0**: 1,247 × 936
#    - Break it down: (1,000 + 200 + 40 + 7) × 936
#    - 1,000 × 936 = 936,000
#    - 200 × 936 = 187,200
#    - 40 × 936 = 37,440
#    - 7 × 936 = 6,552
#    - Sum: 936,000 + 187,200 = 1,123,200
#    - 1,123,200 + 37,440 = 1,160,640
#    - 1,160,640 + 6,552 = 1,167,192
#
# 4. **A0 × B1**: 256 × 548
#    - Break it down: (250 + 6) × 548
#    - 250 × 548 = 137,000
#    - 6 × 548 = 3,288
#    - Sum: 137,000 + 3,288 = 140,288
#
# Now, combine them according to the formula:
# \[ A × B = (A1 × B1) × 10^6 + [(A1 × B0) + (A0 × B1)] × 10^3 + (A0 × B0) \]
#
# Substitute the values:
# - A1 × B1 = 683,356
# - A1 × B0 = 1,167,192
# - A0 × B1 = 140,288
# - A0 × B0 = 239,616
#
# Now, compute the middle term:
# \[ (A1 × B0) + (A0 × B1) = 1,167,192 + 140,288 = 1,307,480 \]
#
# Now, plug into the formula:
# \[ A × B = 683,356 × 10^6 + 1,307,480 × 10^3 + 239,616 \]
#
# Let's break it down:
# 1. 683,356 × 1,000,000 = 683,356,000,000
# 2. 1,307,480 × 1,000 = 1,307,480,000
# 3. Add them: 683,356,000,000 + 1,307,480,000 = 684,663,480,000
# 4. Add the last term: 684,663,480,000 + 239,616 = 684,663,719,616
#
# This matches the previous result, so I can be confident that the multiplication is correct.
#
# ### Step 2: Division by 452,661
#
# Now, I need to divide the result from the multiplication by 452,661.
#
# The number is: 684,663,719,616 / 452,661
#
# #### Understanding the Divisor and Dividend
#
# First, I need to understand the magnitude:
# - Dividend: ~6.8466 × 10^11
# - Divisor: ~4.5266 × 10^5
#
# The quotient should be around 6.8466 × 10^11 / 4.5266 × 10^5 ≈ 1.5126 × 10^6 ≈ 1,512,600.
#
# But I need a more precise calculation.
#
# #### Long Division Approach
#
# Given the complexity, I might need to use a calculator for exact computation, but I can try to estimate.
#
# First, let's see how many times 452,661 fits into 684,663,719,616.
#
# But 452,661 × 1,000,000 = 452,661,000,000
# Subtracting from the dividend: 684,663,719,616 - 452,661,000,000 = 232,002,719,616
#
# Now, 452,661 × 500,000 = 226,330,500,000
# Subtracting: 232,002,719,616 - 226,330,500,000 = 5,672,219,616
#
# Now, 452,661 × 12,000 = 5,431,932,000
# Subtracting: 5,672,219,616 - 5,431,932,000 = 240,287,616
#
# Next, 452,661 × 500 = 226,330,500
# Subtracting: 240,287,616 - 226,330,500 = 13,957,116
#
# Next, 452,661 × 30 = 13,579,830
# Subtracting: 13,957,116 - 13,579,830 = 377,286
#
# Now, 452,661 × 0.8 ≈ 362,128.8
# Subtracting: 377,286 - 362,128.8 ≈ 15,157.2
#
# Now, 452,661 × 0.03 ≈ 13,579.83
# But 15,157.2 is less than 13,579.83, so we need a smaller multiplier.
#
# Let's try 0.033:
# 452,661 × 0.033 ≈ 14,937.813
# Subtracting: 15,157.2 - 14,937.813 ≈ 219.387
#
# Now, 452,661 × 0.00048 ≈ 217.227
# Subtracting: 219.387 - 217.227 ≈ 2.16
#
# At this point, the remainder is negligible.
#
# Now, let's sum up the multipliers:
# 1,000,000 + 500,000 = 1,500,000
# 1,500,000 + 12,000 = 1,512,000
# 1,512,000 + 500 = 1,512,500
# 1,512,500 + 30 = 1,512,530
# 1,512,530 + 0.8 = 1,512,530.8
# 1,512,530.8 + 0.033 ≈ 1,512,530.833
# 1,512,530.833 + 0.00048 ≈ 1,512,530.83348
#
# But, I need a more precise calculation.
#
# #### Using Exact Division
#
# Perhaps using exact division is better. Let's perform the division:
#
# 1. **First Iteration**:
#    - 684,663,719,616 ÷ 452,661 ≈ 1,512,530.83348 (as above)
#
# But, I need a more accurate result. Maybe using a calculator for exact computation.
#
# But since I don't have a calculator, I can use the **Newton-Raphson method** for division.
#
# But that's complex. Alternatively, I can use the **binomial approximation** or **Taylor series**, but it's not straightforward.
#
# ### Using a Calculator for Verification
#
# Since manual computation is tedious, I can think of using a calculator for the final step.
#
# But, for the sake of learning, I can try to find a pattern or use known values.
#
# But, perhaps, the exact value is not necessary, and an approximation is sufficient.
#
# From the previous steps, the result is approximately 1,512,530.83348.
#
# But, I need a more precise value.
#
# ### Final Calculation
#
# Given the complexity, I might need to accept that exact computation is beyond manual calculation.
#
# However, I can use the following approach:
#
# 1. **First, perform the multiplication** as before, which gave 684,663,719,616.
# 2. **Now, divide by 452,661**.
#
# I recall that 452,661 is close to 450,000.
#
# Let's perform the division using the approximation:
#
# - Dividend: 684,663,719,616
# - Divisor: 452,661 ≈ 450,000
#
# First, divide by 450,000:
# 684,663,719,616 / 450,000 ≈ 1,521,474.932566667
#
# Now, adjust for the difference between 452,661 and 450,000.
#
# The difference is 2,661.
#
# Using the approximation:
# \[ \frac{1}{452,661} ≈ \frac{1}{450,000} \left(1 - \frac{2,661}{450,000}\right) \]
#
# But, I'm not sure how this helps directly. Maybe using the Taylor series expansion.
#
# But, perhaps it's easier to stick with the previous result.
#
# ### Conclusion
#
# Given the complexity, I might need to accept that exact computation is non-trivial. However, for practical purposes, the result is approximately 1,512,530.83348.
#
# But, I need a more precise answer. Maybe using exact arithmetic.
#
# ### Exact Calculation
#
# Let's try exact division.
#
# I need to find a number \( x \) such that:
# \[ 452,661 × x = 684,663,719,616 \]
#
# But, exact computation is complex. I can use the **long division** method.
#
# 1. **First Step**: 452,661 × 1,512,530 = ?
#    - Break it down using distributive property:
#      - 1,512,530 = 1,000,000 + 500,000 + 12,000 + 500 + 30
#      - Now, multiply 452,661 by each term:
#        - 452,661 × 1,000,000 = 452,661,000,000
#        - 452,661 × 500,000 = 226,330,500,000
#        - 452,661 × 12,000 = 5,431,932,000
#        - 452,661 × 500 = 226,330,500
#        - 452,661 × 30 = 13,579,830
#      - Sum them up:
#        - 452,661,000,000 + 226,330,500,000 = 678,991,500,000
#        - 678,991,500,000 + 5,431,932,000 = 684,423,432,000
#        - 684,423,432,000 + 226,330,500 = 684,649,762,500
#        - 684,649,762,500 + 13,579,830 = 684,663,342,330
#    - Now, subtract from the original number:
#      - 684,663,719,616 - 684,663,342,330 = 377,286
#
# 2. **Second Step**: Now, divide the remainder 377,286 by 452,661.
#    - 452,661 × 0.83348 ≈ 377,286 (from previous approximation)
#
# Thus, the exact value is approximately 1,512,530.83348.
#
# ### Verification
#
# Let's verify:
# \[ 452,661 × 1,512,530.83348 ≈ 452,661 × 1,512,530 + 452,661 × 0.83348 \]
#
# We already have the first part as 684,663,342,330.
#
# Now, the second part:
# \[ 452,661 × 0.83348 ≈ 452,661 × (0.8 + 0.03 + 0.003 + 0.0004 + 0.00008) \]
# - 452,661 × 0.8 = 362,128.8
# - 452,661 × 0.03 = 13,579.83
# - 452,661 × 0.003 = 1,357.983
# - 452,661 × 0.0004 = 181.0644
# - 452,661 × 0.00008 = 36.21288
# - Sum: 362,128.8 + 13,579.83 = 375,708.63
# - 375,708.63 + 1,357.983 ≈ 377,066.613
# - 377,066.613 + 181.0644 ≈ 377,247.6774
# - 377,247.6774 + 36.21288 ≈ 377,283.89028
#
# Now, add to the previous result:
# 684,663,342,330 + 377,283.89028 ≈ 684,663,719,613.89028
#
# The original number was 684,663,719,616.
#
# The difference is:
# 684,663,719,616 - 684,663,719,613.89028 ≈ 2.10972
#
# This is a very small difference, so the approximation is quite good.
#
# ### Final Answer
#
# Based on the calculations, the result is approximately **1,512,530.83348**.
#
# However, for a more precise answer, exact computation might be necessary, but the approximation is sufficient for most practical purposes.
#
# But, if exact computation is required, perhaps using exact arithmetic or a symbolic computation tool would be better.
#
# For the sake of this exercise, I can conclude with the approximate value.
#
# \boxed{1.51253083348 \times 10^6} (approximately 1,512,530.83348)

# %%
# Calculator tool (plain function)
def calculator(expression: str) -> str:
    """Evaluate a mathematical expression safely for arithmetic purposes.
    Args:
        expression: A math expression like "1247 * 8936 + 4521".
    Returns:
        Result as a string or an error message.
    """
    try:
        return str(eval(expression))
    except Exception as e:
        return f"Error: {e}".strip()

# Quick direct test
print("Testing calculator tool directly:")
print(calculator("1247256 * 548936 / 452661"))
# Out:
# Testing calculator tool directly:
# 1512530.8334846606

# %%
# Calculator via mistralai tool calling
print("=== Calculator via official tool calling ===")
answer = run_tool_chat("What is 1247256 * 548936 / 452661?", [calculator])
print("Final Answer:", answer)
# Out:
# === Calculator via official tool calling ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Tool calculator({'expression': '1247256 * 548936 / 452661'}) -> 1512530.8334846606
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: The result of \( \frac{1247256 \times 548936}{452661} \) is approximately **1,512,530.8335**.

# %% [markdown]
# ### Example 1.2: Vowel Counter Tool
#
# Remember the vowel counting exercise from Notebook 03? LLMs are terrible at it. Let's create a tool to count vowels accurately.

# %%
# Vowel counter tool (plain function)
def count_vowels(text: str) -> str:
    """Count vowels (a,e,i,o,u,y) in text, case-insensitive.
    Args:
        text: Input string.
    Returns:
        Summary string with total and per-vowel breakdown.
    """
    vowels = "aeiouy"
    lower = text.lower()
    counts = {v: lower.count(v) for v in vowels}
    total = sum(counts.values())
    breakdown = ", ".join([f"{v}: {c}" for v, c in counts.items() if c > 0])
    return f"Total vowels: {total} ({breakdown})"

# Direct tests
for word in ["intelligence", "artificielle", "programmation"]:
    print(word, "=>", count_vowels(word))
# Out:
# intelligence => Total vowels: 5 (e: 3, i: 2)
# artificielle => Total vowels: 6 (a: 1, e: 2, i: 3)
# programmation => Total vowels: 5 (a: 2, i: 1, o: 2)

# %%
# Multi-tool capability example using mistralai tool calling
print("=== Multi-Tool (calculator + count_vowels) ===")
capability_answer = run_tool_chat(
    "How many vowels are in the word 'Constantinople'? Then multiply that number by 15.",
    [calculator, count_vowels]
)
print("Final Answer:", capability_answer)
# Out:
# === Multi-Tool (calculator + count_vowels) ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Tool count_vowels({'text': 'Constantinople'}) -> Total vowels: 5 (a: 1, e: 1, i: 1, o: 2)
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: The word "Constantinople" contains 5 vowels. Multiplying that number by 15 gives:
#
# 5 * 15 = 75

# %% [markdown]
# ## Part 2: Knowledge Augmentation
#
# Knowledge augmentation allows LLMs to access information beyond their training data: real-time web content, databases, APIs, and more.
#
# ### Example 2.1: Information search with Wikipedia

# %%
import wikipedia

def search_wikipedia(query: str) -> str:
    """Search Wikipedia for information about a topic.
    Args:
        query: The search query or topic to look up on Wikipedia.
    Returns:
        Summary of the Wikipedia article or error message.
    """
    try:
        # Set language to English
        wikipedia.set_lang("en")
        # Get summary (first few sentences)
        summary = wikipedia.summary(query, sentences=3)
        return summary
    except wikipedia.exceptions.DisambiguationError as e:
        # Multiple possible pages - return the options
        options = ", ".join(e.options[:5])
        return f"Multiple results found. Please be more specific. Options: {options}"
    except wikipedia.exceptions.PageError:
        return f"No Wikipedia page found for '{query}'"
    except Exception as e:
        return f"Wikipedia search error: {e}"

# Test the tool
print("=== Testing Wikipedia Search Tool ===")
print(search_wikipedia("Artificial Intelligence"))
print()
print(search_wikipedia("Python programming"))
# Out:
# === Testing Wikipedia Search Tool ===
# Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
# High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go).
#
# Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
# High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go).
#
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected.
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected.

# %%
# Wikipedia search via mistralai tool calling
print("=== Wikipedia Search Tool Call ===")
wiki_answer = run_tool_chat(
    "Does Brussels have a governement?",
    [search_wikipedia]
)
print("Final Answer:", wiki_answer)
# Out:
# === Wikipedia Search Tool Call ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: Yes, Brussels has a government. The Brussels-Capital Region is one of the three regions of Belgium, alongside Flanders and Wallonia. The government of the Brussels-Capital Region is responsible for managing the region's affairs, including urban development, public works, transportation, and environmental policies.
#
# The Brussels-Capital Region has its own parliament and executive bodies, which are distinct from those of the federal government of Belgium and the governments of the other regions. The government of the Brussels-Capital Region is led by a Minister-President and a team of ministers who are responsible for various policy areas.
#
# Brussels is also the de facto capital of the European Union, and as such, it hosts many of the EU's institutions, including the European Commission, the Council of the European Union, and the European Council. These institutions have their own governance structures and are separate from the government of the Brussels-Capital Region.

# %% [markdown]
# ### Example 2.2: SQL Database Query Tool
#
# Let's create a tool that queries a simple SQLite database. This demonstrates how LLMs can interact with structured data sources.

# %%
# Create a simple SQLite database with student data
import sqlite3

# Create in-memory database
conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create table and insert sample data
cursor.execute('''
CREATE TABLE students (
    id INTEGER PRIMARY KEY,
    name TEXT,
    age INTEGER,
    grade REAL,
    subject TEXT
)
''')

students_data = [
    (1, 'Alice', 20, 85.5, 'Computer Science'),
    (2, 'Bob', 21, 92.0, 'Mathematics'),
    (3, 'Charlie', 19, 78.5, 'Physics'),
    (4, 'Diana', 22, 88.0, 'Computer Science'),
    (5, 'Eve', 20, 95.5, 'Mathematics'),
]

cursor.executemany('INSERT INTO students VALUES (?,?,?,?,?)', students_data)
conn.commit()

print("Sample database created with 5 students")
# Out:
# Sample database created with 5 students

# %%
# Database query tool (plain function)
def query_students_db(query: str) -> str:
    """Execute a read-only SELECT query against the Computer Science students in-memory 
    students grade table that was created with 
    CREATE TABLE students (
    id INTEGER PRIMARY KEY,
    name TEXT,
    age INTEGER,
    grade REAL,
    subject TEXT).
    Args:
        query: SQL SELECT statement.
    Returns:
        Formatted rows or error message.
    """
    try:
        if not query.strip().upper().startswith("SELECT"):
            return "Only SELECT queries allowed"
        cursor.execute(query)
        rows = cursor.fetchall()
        if not rows:
            return "No results"
        return "\n".join(str(r) for r in rows)
    except Exception as e:
        return f"DB error: {e}".strip()

# Quick test
print(query_students_db("SELECT name, grade FROM students WHERE grade > 85"))
# Out:
# ('Alice', 85.5)
# ('Bob', 92.0)
# ('Diana', 88.0)
# ('Eve', 95.5)

# %%
# Database + calculator via mistralai
print("=== Database Tool Call ===")
db_answer = run_tool_chat(
    "What is the average grade of all Computer Science students? Show the numeric average only.",
    [query_students_db, calculator]
)
print("Final Answer:", db_answer)
# Out:
# === Database Tool Call ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Tool query_students_db({'query': "SELECT AVG(grade) FROM students WHERE subject = 'Computer Science';"}) -> (86.75,)
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: The average grade of all Computer Science students is **86.75**.

# %% [markdown]
# ### Example 2.3: Custom API Tool
#
# Let's create a tool that fetches data from a public API. We'll use a simple weather-like API concept.

# %%
import requests, json

# City info tool (plain function)
def get_city_info(city: str) -> str:
    """Lookup basic city info (lat, lon, population) via Open-Meteo geocoding API.
    Args:
        city: City name.
    Returns:
        Multi-line string with details or error.
    """
    try:
        url = f"https://geocoding-api.open-meteo.com/v1/search?name={city}&count=1&language=en&format=json"
        r = requests.get(url, timeout=8)
        r.raise_for_status()
        data = r.json()
        results = data.get("results", [])
        if not results:
            return f"City '{city}' not found"
        res = results[0]
        return (
            f"City: {res.get('name')}\n" \
            f"Country: {res.get('country')}\n" \
            f"Latitude: {res.get('latitude')}\n" \
            f"Longitude: {res.get('longitude')}\n" \
            f"Population: {res.get('population', 'N/A')}"
        )
    except Exception as e:
        return f"City info error: {e}".strip()

# Quick test
print(get_city_info("Brussels"))
# Out:
# City: Brussels
# Country: Belgium
# Latitude: 50.85045
# Longitude: 4.34878
# Population: 1019022

# %%
# City info + calculator via mistralai
print("=== City Info Tool Call ===")
city_answer = run_tool_chat(
    "What is the population of Paris? Multiply it by 2 and show the result.",
    [get_city_info, calculator]
)
print("Final Answer:", city_answer)
# Out:
# === City Info Tool Call ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Tool get_city_info({'city': 'Paris'}) -> City: Paris
# Country: France
# Latitude: 48.85341
# Longitude: 2.3488
# Population: 2138551
# Tool calculator({'expression': 'population * 2'}) -> Error: name 'population' is not defined
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: It appears there was an error in the calculation. Let me try again.
#
# The population of Paris is 2,138,551. Multiplying this by 2 gives:
#
# 2,138,551 * 2 = 4,277,102

# %% [markdown]
# ## Part 3: Combining Multiple Tools
#
# The real power of tools comes from combining them. Let's create an agent with access to all our tools and see it solve complex, multi-step problems.

# %%
# Comprehensive multi-tool example via mistralai tool calling
print("=== Comprehensive Multi-Tool Call ===")
complex_final = run_tool_chat(
    """Find the student with the highest grade, count vowels in their name, multiply that count by the grade, then compare that product to twice the population of Brussels (if population known).""",
    [query_students_db, count_vowels, calculator, get_city_info]
)
print("Final Answer:", complex_final)
# Out:
# === Comprehensive Multi-Tool Call ===
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Tool query_students_db({'query': 'SELECT name, grade FROM students ORDER BY grade DESC LIMIT 1;'}) -> ('Eve', 95.5)
# Tool get_city_info({'city': 'Brussels'}) -> City: Brussels
# Country: Belgium
# Latitude: 50.85045
# Longitude: 4.34878
# Population: 1019022
# Tool get_city_info({'city': 'Brussels'}) -> City: Brussels
# Country: Belgium
# Latitude: 50.85045
# Longitude: 4.34878
# Population: 1019022
# WARNING: The model mistral-small is deprecated and will be removed on 2024-11-30T12:00:00+00:00. Please refer to https://docs.mistral.ai/getting-started/models/#api-versioning for more information.
# Final Answer: ### Analysis
#
# 1. **Student with the highest grade**: Eve (Grade: 95.5)
# 2. **Count of vowels in the student's name**:
#    - Name: "Eve"
#    - Vowels: E, e (2 vowels)
# 3. **Multiply the vowel count by the grade**:
#    - Calculation: 2 * 95.5 = 191
# 4. **Twice the population of Brussels**:
#    - Population of Brussels: 1,019,022
#    - Calculation: 2 * 1,019,022 = 2,038,044
#
# ### Comparison
# The product of the vowel count and the grade (191) is significantly smaller than twice the population of Brussels (2,038,044).

# %% [markdown]
# ## Exercise: Create Your Own Tool
#
# Design and implement a custom tool for one of these scenarios:
#
# ### Option 1: Date/Time Tool
# Create a tool that answers questions about dates and times:
# - Days between two dates
# - Day of the week for any date
# - Add/subtract days from a date
# - Time zone conversions
#
# ### Option 2: Text Analysis Tool
# Create a tool that analyzes text:
# - Word count and unique word count
# - Reading time estimation
# - Sentence count
# - Most common words
#
# ### Option 3: Unit Converter Tool
# Create a tool that converts between units:
# - Temperature (Celsius, Fahrenheit, Kelvin)
# - Length (meters, feet, miles, km)
# - Weight (kg, lbs, oz)
# - Currency (mock exchange rates)
