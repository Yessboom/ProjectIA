# %% [markdown]
# # Prompt Engineering — Example Code Review and Grading
#
# - Author: Martin Fockedey with the help of copilote
#
# In this notebook, we progressively improve a task using prompt engineering techniques. The task is to review a student's code, assign a grade, and provide improvement advice.
#
# We will compare outputs across six techniques:
#
# 1. Clear and explicit instruction
# 2. Provide sufficient context (requirements + rubric)
# 3. Use a reviewer persona (supportive, rigorous CS teacher)
# 4. Structured Output for Automation
# 5. Few-shot examples
# 6. Fractioning into subtasks with structured output
# 7. Concise rationale (CoT-style bullets)

# %% [markdown]
# ## Environment Setup
#
# Set up the environment.
#
# [Note]
# - You'll need a Mistral AI API key (see your Teams group channel).
# - Store your API key in a `.env` file as `MISTRAL_API_KEY`.

# %%
# Imports and environment setup
import os
from dotenv import load_dotenv

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_mistralai import ChatMistralAI

load_dotenv(override=True)

if not os.getenv("MISTRAL_API_KEY"):
    print("Warning: MISTRAL_API_KEY is not set. Set it in your .env to run LLM calls.")

MODEL_NAME = os.getenv("MISTRAL_MODEL", "mistral-small")
TEMPERATURE = float(os.getenv("MISTRAL_TEMPERATURE", "0.3"))

llm = ChatMistralAI(model=MODEL_NAME, temperature=TEMPERATURE)
parser = StrOutputParser()

# Helper to run a template with variables

def run_chain(template: str, variables: dict):
    prompt = PromptTemplate.from_template(template)
    chain = prompt | llm | parser
    return chain.invoke(variables)

# %%
# Sample task context and student submission

task_description = (
    "Write a function `average(nums)` that returns the arithmetic mean "
    "of a list of numbers. If the list is empty, raise `ValueError`."
)

# A deliberately buggy student implementation
student_code = r"""
# Student code to review

def average(nums):
    total = 0
    for i in range(len(nums)):
        total += i  
    return total / len(nums)  
"""
#Two issues: Missing empty-list handling + adds index, not value
grading_rubric = (
    "Assess on: (1) Correctness (40%), (2) Robustness/Edge Cases (25%), "
    "(3) Code Quality/Clarity (20%), (4) Efficiency (10%), (5) Style (5%)."
)

print("Task and student code loaded.")
# Out:
# Task and student code loaded.

# %% [markdown]
# ## 0) A Weak Prompt (What Not To Do)
# This deliberately poor prompt shows common mistakes:
# - Vague request ("fix stuff")
# - No task requirement restatement
# - No grading rubric or desired structure
# - Ambiguous output format (mixes prose + code)
# - No explicit keys for downstream parsing
#
# Observe how the model output may be: incomplete, inconsistent, missing a grade, or providing superficial advice.
#
# Goal: Use this as a baseline to compare improvements in Sections 1–6.

# %%
# Weak prompt example (DO NOT COPY AS BEST PRACTICE)
weak_prompt_template = (
    "Here is some code. Fix it and say what you think.\n"  # vague instruction
    f"{student_code}\n"  # raw code dumped without requirement
    "Give me feedback."  # no structure, no rubric
)

# Uncomment to run once API key is set:
print(run_chain(weak_prompt_template, {}))
# Out:
# Here's the fixed code with explanations:
#
# ```python
# def average(nums):
#     if not nums:  # Handle empty list case
#         return 0  # or raise an exception, depending on requirements
#     total = 0
#     for num in nums:  # Iterate through values, not indices
#         total += num
#     return total / len(nums)
# ```
#
# Key issues fixed:
# 1. **Index vs Value**: The original code added the index `i` instead of the actual number `nums[i]`. I fixed this by iterating directly through the values using `for num in nums`.
# 2. **Empty List Handling**: The original code would raise a `ZeroDivisionError` if an empty list was passed. I added a check at the beginning to handle this case.
# 3. **Readability**: The fixed version is more Pythonic by iterating through values directly rather than using indices.
#
# Additional considerations:
# - You might want to return `None` or raise a `ValueError` instead of returning 0 for empty lists, depending on your requirements.
# - For very large lists, you could use `sum(nums) / len(nums)` for better performance and readability.
# - The function name `average` is good, but you might want to consider `mean` if you're following statistical naming conventions.
#
# The fixed version is more robust and handles edge cases properly while maintaining the original functionality for valid inputs.

# %% [markdown]
# ## 1) Clear and Explicit Instruction
# We start with a very clear instruction: what the assistant must deliver.

# %%
baseline_template = (
    "You are reviewing a student's code. You need to correct the code, assign a grade, and provide advice.\n"
    "Student code:\n{student_code}\n"
)

print(run_chain(baseline_template, {"student_code": student_code}))
# Out:
# Here's my review of the student's code:
#
# ### Corrected Code:
# ```python
# def average(nums):
#     if not nums:  # Handle empty list case
#         return 0  # or raise an exception, depending on requirements
#     total = 0
#     for num in nums:  # Iterate through values, not indices
#         total += num
#     return total / len(nums)
# ```
#
# ### Grade: 6/10
# - **Deductions:**
#   - 2 points for the major bug (adding indices instead of values)
#   - 1 point for missing empty list handling
#   - 1 point for less Pythonic iteration (using indices when values are needed)
#
# ### Feedback:
# 1. **Main Issues:**
#    - The code adds array indices (`i`) instead of the actual numbers (`nums[i]` or `num` in a direct iteration)
#    - No handling for empty lists (which would cause division by zero)
#
# 2. **Improvements:**
#    - Use direct iteration (`for num in nums`) instead of index-based access
#    - Add input validation for empty lists
#    - Consider using `sum(nums) / len(nums)` for a more Pythonic solution
#
# 3. **Additional Advice:**
#    - Always test edge cases (empty list, single-element list, etc.)
#    - Consider whether returning 0 for empty lists is appropriate (alternative: raise ValueError)
#    - The function name `average` is good, but you might want to add type hints for better documentation
#
# 4. **Example of More Pythonic Version:**
# ```python
# def average(nums: list[float]) -> float:
#     """Calculate the average of numbers in a list."""
#     if not nums:
#         raise ValueError("Cannot calculate average of empty list")
#     return sum(nums) / len(nums)
# ```
#
# The student shows basic understanding of loops and arithmetic operations but needs to pay more attention to variable usage and edge cases. With these corrections, the function would work properly.

# %% [markdown]
# The code is corrected but the grade won't be consistent between different calls ...

# %% [markdown]
# ## 2) Provide Sufficient Context
# Add the assignment requirements so that the model knows what was expected from the student and a grading rubric. This helps the model judge correctness, prioritize what matters and to be consistent.

# %%
context_template = (
    "You are reviewing a student's code for an assignment.\n" \
    "Assignment requirement: {task_description}\n" \
    "Grading rubric: {grading_rubric}\n" \
    "Deliverables: (1) corrected_code, (2) grade (0-100), (3) advice (array).\n" \
    "Student code:\n{student_code}\n"
)

print(run_chain(context_template, {
    "task_description": task_description,
    "grading_rubric": grading_rubric,
    "student_code": student_code
}))
# Out:
# Here's the review of the student's code:
#
# ### (1) Corrected Code:
# ```python
# def average(nums):
#     if not nums:  # Check for empty list
#         raise ValueError("Cannot compute average of an empty list")
#     total = 0
#     for num in nums:  # Iterate over values, not indices
#         total += num
#     return total / len(nums)
# ```
#
# ### (2) Grade: 50/100
# - **Correctness (40%)**: 0/40 (Major bug: adds indices instead of values, no empty list handling)
# - **Robustness/Edge Cases (25%)**: 0/25 (Fails on empty list, no other edge case handling)
# - **Code Quality/Clarity (20%)**: 10/20 (Simple structure but critical logical error)
# - **Efficiency (10%)**: 10/10 (O(n) time is optimal for this problem)
# - **Style (5%)**: 5/5 (Good variable naming, but buggy logic)
#
# ### (3) Advice:
# 1. **Correct the logical error**: The loop should iterate over the values (`for num in nums`) rather than indices.
# 2. **Handle empty list**: Add a check at the start to raise `ValueError` if the list is empty.
# 3. **Consider using built-in functions**: While not required, `sum(nums) / len(nums)` would be more concise.
# 4. **Test edge cases**: Test with empty list, single-element list, and negative numbers to ensure robustness.
#
# The code fails the basic requirements but shows a good attempt at the structure. With the fixes, it would be fully functional.

# %% [markdown]
# The result is quite good but the tone is a bit cold and doesn't take a real pedagogical approach.

# %% [markdown]
# ## 3) Use a Persona
# Adopt a specific reviewer persona (e.g., a supportive but rigorous CS teacher). Personae guide tone, structure, and priorities.

# %%
persona_template = (
    "Act as a supportive but rigorous computer science teacher.\n" \
    "Your tone should be constructive, specific, and pedagogical.\n" \
    "You are reviewing a student's code for an assignment.\n" \
    "Assignment requirement: {task_description}\n" \
    "Grading rubric: {grading_rubric}\n" \
    "Deliverables: corrected_code, grade (0-100), advice (array).\n" \
    "\n" \
    "Student code:\n{student_code}\n"
)

print(run_chain(persona_template, {
    "task_description": task_description,
    "grading_rubric": grading_rubric,
    "student_code": student_code
}))
# Out:
# ### **Code Review & Feedback**
#
# #### **1. Correctness (0/40)**
# The function does not correctly compute the arithmetic mean. The main issue is that it sums the **indices** (`i`) instead of the **values** (`nums[i]`). Additionally, it fails to handle the empty-list case, which should raise a `ValueError`.
#
# #### **2. Robustness/Edge Cases (0/25)**
# - **Empty list**: No error is raised when the input list is empty, which violates the assignment requirements.
# - **Non-numeric inputs**: The function does not check if the input list contains non-numeric values (e.g., strings), which could lead to runtime errors.
#
# #### **3. Code Quality/Clarity (10/20)**
# - The variable name `total` is clear, but the loop logic is incorrect.
# - The function lacks comments or docstrings, which would improve readability.
#
# #### **4. Efficiency (10/10)**
# The function is **O(n)** in time complexity, which is optimal for this task. No further optimization is needed.
#
# #### **5. Style (3/5)**
# - The function name `average` is descriptive.
# - The loop could be simplified using `for num in nums` instead of `for i in range(len(nums))`.
#
# ---
#
# ### **Corrected Code**
# ```python
# def average(nums):
#     """Compute the arithmetic mean of a list of numbers.
#
#     Args:
#         nums (list): A list of numbers.
#
#     Returns:
#         float: The arithmetic mean of the numbers.
#
#     Raises:
#         ValueError: If the input list is empty.
#     """
#     if not nums:
#         raise ValueError("Cannot compute average of an empty list.")
#
#     total = 0
#     for num in nums:  # Iterate directly over values, not indices
#         total += num
#
#     return total / len(nums)
# ```
#
# ---
#
# ### **Grade: 23/100**
# - **Correctness**: 0/40 (incorrect logic, missing error handling)
# - **Robustness**: 0/25 (no edge-case handling)
# - **Code Quality**: 10/20 (clear variable names, but missing docstring)
# - **Efficiency**: 10/10 (optimal)
# - **Style**: 3/5 (good name, but could be improved)
#
# ---
#
# ### **Advice for Improvement**
# 1. **Fix the logic**: Sum the values (`nums[i]` or `num` in a direct loop), not the indices.
# 2. **Handle edge cases**: Raise `ValueError` for empty lists.
# 3. **Add input validation**: Ensure all elements are numeric (e.g., using `isinstance(num, (int, float))`).
# 4. **Improve readability**:
#    - Use a docstring to explain the function.
#    - Consider using `sum(nums) / len(nums)` for conciseness (if allowed).
# 5. **Test thoroughly**: Test with empty lists, single-element lists, and non-numeric inputs.
#
# Would you like to revise your solution and resubmit for another review? Keep up the effort—you're on the right track! 🚀

# %% [markdown]
# ## 4) Structured Output for Automation
# To enable automated processing (e.g., collecting points per rubric), require a strict JSON structure. This reduces ambiguity and makes results machine-usable.
#
# Requested JSON shape:
# - corrected_code: string
# - grade: number (0–100)
# - scores: object with keys {correctness (0–40), robustness (0–25), quality (0–20), efficiency (0–10), style (0–5)}
# - advice: array of short strings
#
# Rules:
# - Return a single JSON object only — no extra prose.
# - Ensure each score is an integer within its cap; grade equals the sum of scores.

# %%
json_template = (
    "Act as a supportive but rigorous computer science teacher.\n"
    "You are reviewing a student's code for an assignment.\n"
    "Assignment requirement: {task_description}\n"
    "Grading rubric: {grading_rubric}\n"
    "Return ONLY a JSON object with these keys:\n"
    "- corrected_code: string containing the fixed code\n"
    "- grade: number (0-100), must equal sum of all scores\n"
    "- scores: object with correctness (0-40), robustness (0-25), quality (0-20), efficiency (0-10), style (0-5)\n"
    "- advice: array of short, actionable improvement suggestions\n"
    "Constraints: grade MUST equal correctness+robustness+quality+efficiency+style. No extra text outside the JSON.\n\n"
    "Student code:\n{student_code}\n"
)

print(run_chain(json_template, {
    "task_description": task_description,
    "grading_rubric": grading_rubric,
    "student_code": student_code
}))
# Out:
# ```json
# {
#   "corrected_code": "def average(nums):\n    if not nums:\n        raise ValueError(\"List cannot be empty\")\n    return sum(nums) / len(nums)",
#   "grade": 65,
#   "scores": {
#     "correctness": 0,
#     "robustness": 25,
#     "quality": 20,
#     "efficiency": 10,
#     "style": 10
#   },
#   "advice": [
#     "Fix the bug where you're adding indices instead of values",
#     "Add empty list handling to raise ValueError",
#     "Consider using built-in sum() for cleaner code",
#     "Add docstring to explain function purpose",
#     "Use more descriptive variable names if needed"
#   ]
# }
# ```

# %% [markdown]
# ## 5) Examples and Few-Shot Learning
# Provide one or two compact examples of the desired input-output behavior. Examples calibrate style, structure, and depth.

# %%
fewshot_template = (
    "Act as a supportive but rigorous computer science teacher.\n" \
    "You are reviewing a student's code for an assignment.\n" \
    "Assignment requirement: {task_description}\n" \
    "Grading rubric: {grading_rubric}\n" \
    "Deliverables: corrected_code, grade (0-100), advice (array). Return JSON.\n" \
    "\n" \
    "Example 1 — Input code:\n"
    "def add(a,b):\n    return a-b\n" \
    "Example 1 — Desired JSON output:\n"
    "{{\n"
    "  \"corrected_code\": \"def add(a, b):\\n    return a + b\",\n"
    "  \"grade\": 70,\n"
    "  \"advice\": [\"Add docstrings\", \"Use spaces around operators\"]\n"
    "}}\n" \
    "\n" \
    "Example 2 — Input code:\n"
    "def divide(a,b):\n    return a/b\n" \
    "Example 2 — Desired JSON output:\n"
    "{{\n"
    "  \"corrected_code\": \"def divide(a, b):\\n    if b == 0:\\n        raise ZeroDivisionError(\'division by zero\')\\n    return a / b\",\n"
    "  \"grade\": 85,\n"
    "  \"advice\": [\"Handle division by zero\", \"Add type hints\"]\n"
    "}}\n" \
    "\n" \
    "Now review this Student code and return JSON as above:\n{student_code}\n"
)

print(run_chain(fewshot_template, {
    "task_description": task_description,
    "grading_rubric": grading_rubric,
    "student_code": student_code
}))
# Out:
# ```json
# {
#   "corrected_code": "def average(nums):\n    if not nums:\n        raise ValueError('Cannot compute average of an empty list')\n    total = 0\n    for num in nums:\n        total += num\n    return total / len(nums)",
#   "grade": 60,
#   "advice": [
#     "Handle empty list case by raising ValueError",
#     "Use the list elements directly in the loop instead of indices",
#     "Add docstring to explain the function's purpose and parameters",
#     "Consider adding type hints for better code clarity",
#     "Use meaningful variable names (e.g., 'total' is fine, but 'num' could be more descriptive)"
#   ]
# }
# ```

# %% [markdown]
# ## 6) Fractioning into Subtasks
# Explicitly break the task into steps and ask for a structured, multi-part result. This reduces ambiguity and improves coverage of requirements.

# %%
subtasks_template = (
    "Role: supportive, rigorous CS teacher.\n" \
    "Requirement: {task_description}\n" \
    "Rubric: {grading_rubric}\n" \
    "Follow these subtasks:\n" \
    "1) Validate the implementation against the requirement (incl. empty list).\n" \
    "2) List specific defects you find (line- or behavior-based).\n" \
    "3) Provide corrected_code that fully meets the requirement.\n" \
    "4) Assign a grade (0-100) using the rubric.\n" \
    "5) Provide actionable advice as an array of short, concrete suggestions.\n" \
    "Output your reasoning for each task and at the end give a JSON with keys: checks (array), bugs (array), corrected_code (string), grade (number), advice (array).\n" \
    "\n" \
    "Student code:\n{student_code}\n"
)

print(run_chain(subtasks_template, {
    "task_description": task_description,
    "grading_rubric": grading_rubric,
    "student_code": student_code
}))
# Out:
# ### Task 1: Validate the implementation against the requirement
# The student's function `average(nums)` is intended to compute the arithmetic mean of a list of numbers. However, it has several issues:
# 1. **Correctness (40%)**: The function incorrectly sums the indices (`i`) of the list elements instead of the elements themselves (`nums[i]`). This will always return a wrong result.
# 2. **Robustness/Edge Cases (25%)**: The function does not handle the empty list case as required. It will raise a `ZeroDivisionError` instead of a `ValueError`.
# 3. **Code Quality/Clarity (20%)**: The code is not clear because it uses `i` (an index) instead of the actual list elements. The variable name `total` is misleading since it doesn't represent the sum of the numbers.
# 4. **Efficiency (10%)**: The function is inefficient because it uses `range(len(nums))` to iterate, which is less Pythonic than directly iterating over the list.
# 5. **Style (5%)**: The style is not ideal due to the incorrect logic and lack of proper handling of edge cases.
#
# ### Task 2: List specific defects
# 1. **Line 3**: `total += i` sums the indices instead of the list elements (`nums[i]`).
# 2. **Line 4**: No check for an empty list, which will cause a `ZeroDivisionError`.
# 3. **General**: The function does not meet the requirement of raising a `ValueError` for an empty list.
#
# ### Task 3: Corrected code
# Here is the corrected implementation:
# ```python
# def average(nums):
#     if not nums:
#         raise ValueError("List cannot be empty")
#     return sum(nums) / len(nums)
# ```
#
# ### Task 4: Assign a grade
# Using the rubric:
# 1. **Correctness (40%)**: 0% (incorrect logic, wrong sum, no error handling).
# 2. **Robustness/Edge Cases (25%)**: 0% (no handling of empty list).
# 3. **Code Quality/Clarity (20%)**: 10% (misleading variable names, unclear logic).
# 4. **Efficiency (10%)**: 5% (inefficient iteration, but not the main issue).
# 5. **Style (5%)**: 0% (poor style due to incorrect logic).
# **Total grade: 15/100**
#
# ### Task 5: Actionable advice
# 1. Always validate inputs (e.g., check for empty lists).
# 2. Use meaningful variable names (e.g., `sum_of_numbers` instead of `total`).
# 3. Iterate directly over the list elements instead of using indices.
# 4. Use built-in functions like `sum()` for clarity and efficiency.
# 5. Follow Python style guidelines (PEP 8) for better readability.
#
# ### Final JSON output:
# ```json
# {
#   "checks": [
#     "Function sums indices instead of list elements",
#     "No handling of empty list (raises ZeroDivisionError instead of ValueError)",
#     "Variable names are misleading",
#     "Inefficient iteration using range(len(nums))"
#   ],
#   "bugs": [
#     "Line 3: total += i should be total += nums[i]",
#     "Line 4: Missing check for empty list"
#   ],
#   "corrected_code": "def average(nums):\n    if not nums:\n        raise ValueError(\"List cannot be empty\")\n    return sum(nums) / len(nums)",
#   "grade": 15,
#   "advice": [
#     "Always validate inputs (e.g., check for empty lists)",
#     "Use meaningful variable names (e.g., sum_of_numbers instead of total)",
#     "Iterate directly over the list elements instead of using indices",
#     "Use built-in functions like sum() for clarity and efficiency",
#     "Follow Python style guidelines (PEP 8) for better readability"
#   ]
# }
# ```

# %% [markdown]
# ## 7) CoT Reasoning
# The goal of CoT is to ask the LLM to give a reasoning, it improves performance (it replace a direct guess by a longer causal reasoning) and explainability/transparancy as it shows why the LLM gave this response allowing us to audit it.
#
# The CoT is nowdays embedded in the last training phase of the models and it's usually not necessary to explicit it in the prompt anymore. You can still see the improvement with or without reasoning by asking the AI not to give a reasoning

# %%
print("Without the chain of thought reasoning:")
noCoT =  "A train leaves Station A at 8:00 AM traveling at 60 km/h. Another train leaves Station B at 9:00 AM " \
"traveling at 80 km/h toward Station A. If the stations are 300 km apart, at what time will the two trains meet? " \
"Don't think step-by-step and give no reasoning. Just give the response."
print(run_chain(noCoT, {}))

print("With the chain of thought reasoning:")
CoT =  "A train leaves Station A at 8:00 AM traveling at 60 km/h. Another train leaves Station B at 9:00 AM " \
"traveling at 80 km/h toward Station A. If the stations are 300 km apart, at what time will the two trains meet? "
print(run_chain(CoT, {}))
# Out:
# Without the chain of thought reasoning:
# 10:30 AM.
# With the chain of thought reasoning:
# 10:30 AM.
# With the chain of thought reasoning:
# Alright, let's tackle this problem step by step. I'm going to think about the two trains moving towards each other and figure out when and where they'll meet.
#
# ### Understanding the Problem
#
# We have two stations, Station A and Station B, which are 300 kilometers apart.
#
# - **Train 1**: Leaves Station A at 8:00 AM, traveling at 60 km/h towards Station B.
# - **Train 2**: Leaves Station B at 9:00 AM, traveling at 80 km/h towards Station A.
#
# We need to determine the time at which these two trains will meet each other.
#
# ### Visualizing the Scenario
#
# First, let's visualize the situation:
#
# - At 8:00 AM:
#   - Train 1 starts from Station A towards Station B at 60 km/h.
#   - Train 2 is still at Station B; it hasn't left yet.
#
# - From 8:00 AM to 9:00 AM (one hour):
#   - Train 1 is moving towards Station B.
#   - Train 2 is still at Station B.
#
# At 9:00 AM:
# - Train 1 has been traveling for 1 hour at 60 km/h, so it has covered:
#   - Distance = Speed × Time = 60 km/h × 1 h = 60 km.
#   - So, at 9:00 AM, Train 1 is 60 km away from Station A towards Station B.
#   - Therefore, the remaining distance between Train 1 and Station B is:
#     - Total distance - distance covered by Train 1 = 300 km - 60 km = 240 km.
#
# Now, at 9:00 AM:
# - Train 2 starts from Station B towards Station A at 80 km/h.
# - Train 1 is at the 60 km mark from Station A, moving towards Station B at 60 km/h.
# - The distance between the two trains at 9:00 AM is 240 km.
#
# ### Relative Speed Concept
#
# When two objects are moving towards each other, their relative speed is the sum of their individual speeds.
#
# - Speed of Train 1: 60 km/h
# - Speed of Train 2: 80 km/h
# - Relative speed when moving towards each other: 60 + 80 = 140 km/h
#
# This means that the distance between the two trains is decreasing at a rate of 140 km every hour.
#
# ### Calculating Time to Meet After 9:00 AM
#
# At 9:00 AM, the distance between the two trains is 240 km, and they're closing that distance at 140 km/h.
#
# Time taken to meet after 9:00 AM = Distance / Relative Speed
# = 240 km / 140 km/h
# = 24/14 hours
# = 12/7 hours
# ≈ 1.714 hours
#
# To convert 0.714 hours to minutes:
# 0.714 × 60 ≈ 42.857 minutes
#
# So, approximately 1 hour and 43 minutes after 9:00 AM.
#
# Adding that to 9:00 AM:
# 9:00 AM + 1 hour = 10:00 AM
# 10:00 AM + 43 minutes ≈ 10:43 AM
#
# But let's calculate it more precisely without approximating:
#
# 12/7 hours = 1 hour + (5/7) hours
# (5/7) hours = (5/7) × 60 minutes ≈ 42.857 minutes
#
# So, 1 hour and ~42.857 minutes after 9:00 AM is approximately 10:42:51 AM.
#
# However, since the speeds are given as whole numbers, it's likely that the exact time is a simple fraction. Let's see:
#
# 12/7 hours is exactly 1 hour and 42 + 6/7 minutes, which is 1 hour, 42 minutes, and about 51.428 seconds.
#
# But in practical terms, we can say they meet at approximately 10:43 AM.
#
# But let's check if we can express it exactly.
#
# ### Alternative Approach: Using Equations
#
# Let's define the time from 8:00 AM as 't' hours.
#
# - Train 1:
#   - Departs at t=0 (8:00 AM).
#   - Speed: 60 km/h.
#   - Distance covered by Train 1 at time t: D1 = 60t.
#
# - Train 2:
#   - Departs at t=1 (9:00 AM).
#   - Speed: 80 km/h.
#   - Distance covered by Train 2 at time t: D2 = 80(t - 1), for t ≥ 1.
#
# The sum of the distances covered by both trains when they meet should be equal to the total distance between the stations, which is 300 km.
#
# So, D1 + D2 = 300
# 60t + 80(t - 1) = 300
#
# Now, solve for t:
#
# 60t + 80t - 80 = 300
# 140t - 80 = 300
# 140t = 300 + 80
# 140t = 380
# t = 380 / 140
# t = 38 / 14
# t = 19 / 7 hours
#
# Now, convert 19/7 hours to hours and minutes:
#
# 19 ÷ 7 = 2 with a remainder of 5, so 2 and 5/7 hours.
#
# 5/7 hours = (5/7) × 60 ≈ 42.857 minutes.
#
# So, t = 2 hours and ~42.857 minutes after 8:00 AM.
#
# 8:00 AM + 2 hours = 10:00 AM
# 10:00 AM + ~42.857 minutes ≈ 10:42:51 AM.
#
# This matches our previous calculation.
#
# ### Verifying the Answer
#
# Let's verify by calculating the distances covered by each train at t = 19/7 hours.
#
# - Train 1:
#   - Distance = 60 × (19/7) = 1140 / 7 ≈ 162.857 km from Station A.
#
# - Train 2:
#   - Time traveled = t - 1 = 19/7 - 7/7 = 12/7 hours.
#   - Distance = 80 × (12/7) = 960 / 7 ≈ 137.143 km from Station B.
#
# Adding both distances: 162.857 + 137.143 ≈ 300 km, which matches the total distance between the stations.
#
# ### Conclusion
#
# The two trains will meet at approximately **10:42:51 AM**. However, since the problem likely expects an exact fraction, we can say they meet at **19/7 hours after 8:00 AM**, which is **2 hours and 5/7 hours after 8:00 AM**, or more precisely, **10:42 and 6/7 minutes AM**.
#
# But in practical terms, it's reasonable to say they meet at **10:43 AM**.
#
# However, looking back at the initial approach where we calculated the time after 9:00 AM as 12/7 hours, which is 1 hour and 5/7 hours, leading to 10:42:51 AM, seems consistent.
#
# Given that, the exact time is **19/7 hours after 8:00 AM**, which is **10:42:51 AM**.
#
# But since the options or the format might expect a simpler answer, and considering that 19/7 hours is approximately 2.714 hours, which is 2 hours and ~42.857 minutes, the most precise answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But in decimal terms, it's approximately 10:42:51 AM.
#
# Given that, and since the problem doesn't specify the format, the exact time is **19/7 hours after 8:00 AM**, which is **10:42:51 AM**.
#
# However, if we're to present it in a more conventional time format without fractions, we might say:
#
# **The two trains will meet at approximately 10:43 AM.**
#
# But to be precise, it's exactly at **10:42 and 6/7 minutes AM**.
#
# Given that, and considering that the initial calculation after 9:00 AM was 12/7 hours, which is 1 hour and 5/7 hours, leading to 10:42:51 AM, that seems correct.
#
# ### Final Answer
#
# After carefully working through the problem, the two trains will meet at **10:42 and 6/7 minutes AM**, or approximately **10:43 AM**.
#
# Expressed precisely:
#
# - **Time after 8:00 AM when they meet:** 19/7 hours (which is 2 hours and 5/7 hours).
# - **Converted to minutes:** 5/7 hours = 42 + 6/7 minutes.
# - **Therefore, they meet at:** 10:42 and 6/7 minutes AM.
#
# So, the exact time is **10:42 and 6/7 minutes AM**.
#
# In practical terms, this is approximately **10:43 AM**.
#
# But the precise answer is **10:42 and 6/7 minutes AM**.
#
# However, since the problem likely expects a time in hours and minutes without fractions, and given that 6/7 minutes is about 51.428 seconds, the closest conventional time is **10:43 AM**.
#
# But to be mathematically precise, it's **10:42 and 6/7 minutes AM**.
#
# Given that, and considering that the options might not have such precise times, the most accurate answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But if we're to choose the closest conventional time, it's **10:43 AM**.
#
# Given that, and since the initial calculation after 9:00 AM was 12/7 hours (1 hour and 5/7 hours), leading to 10:42:51 AM, the precise answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But in decimal terms, that's approximately 10:42:51 AM.
#
# Therefore, the exact time is **10:42 and 6/7 minutes AM**.
#
# ### Simplified Exact Answer
#
# To present it clearly:
#
# - **Total time from 8:00 AM until meeting:** 19/7 hours = 2 hours and 5/7 hours.
# - **5/7 hours = 42 + 6/7 minutes.**
# - **So, 8:00 AM + 2 hours = 10:00 AM.**
# - **Add 42 + 6/7 minutes to 10:00 AM: 10:42 and 6/7 minutes AM.**
#
# Thus, the two trains meet at **10:42 and 6/7 minutes AM**.
#
# ### Final Presentation
#
# After carefully working through the problem, the exact time at which the two trains meet is:
#
# **10:42 and 6/7 minutes AM.**
#
# This is approximately **10:43 AM**.
#
# But the precise answer is **10:42 and 6/7 minutes AM**.
#
# ### Step-by-Step Summary
#
# 1. **From 8:00 AM to 9:00 AM:**
#    - Only Train 1 is moving.
#    - Distance covered by Train 1: 60 km.
#    - Remaining distance between Train 1 and Station B: 300 - 60 = 240 km.
#
# 2. **At 9:00 AM:**
#    - Train 2 starts from Station B towards Station A.
#    - Distance between the two trains: 240 km.
#    - Relative speed towards each other: 60 + 80 = 140 km/h.
#
# 3. **Time to meet after 9:00 AM:**
#    - Time = Distance / Relative Speed = 240 / 140 = 12/7 hours = 1 hour and 5/7 hours.
#
# 4. **Adding to 9:00 AM:**
#    - 1 hour after 9:00 AM is 10:00 AM.
#    - 5/7 hours = 42 + 6/7 minutes.
#    - So, 10:00 AM + 42 + 6/7 minutes = 10:42 and 6/7 minutes AM.
#
# Therefore, the two trains meet at **10:42 and 6/7 minutes AM**.
#
# ### Verification
#
# Let's verify the distances:
#
# - **Train 1:**
#   - Total time from 8:00 AM: 19/7 hours.
#   - Distance: 60 * (19/7) = 1140/7 ≈ 162.857 km from Station A.
#
# - **Train 2:**
#   - Time from 9:00 AM: 12/7 hours.
#   - Distance: 80 * (12/7) = 960/7 ≈ 137.143 km from Station B.
#
# Total distance: 162.857 + 137.143 = 300 km, which matches the distance between the stations.
#
# Thus, the calculations are correct.
#
# ### Final Answer
#
# The two trains will meet at **10:42 and 6/7 minutes AM**.
#
# Expressed differently, this is **19/7 hours after 8:00 AM**, which is **2 hours and 5/7 hours after 8:00 AM**, leading to **10:42 and 6/7 minutes AM**.
#
# In decimal terms, this is approximately **10:42:51 AM**.
#
# Therefore, the precise time is **10:42 and 6/7 minutes AM**.
#
# If an exact fraction is acceptable, that's the answer. If a conventional time is preferred, it's approximately **10:43 AM**.
#
# Given that, the exact answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
# Alright, let's tackle this problem step by step. I'm going to think about the two trains moving towards each other and figure out when and where they'll meet.
#
# ### Understanding the Problem
#
# We have two stations, Station A and Station B, which are 300 kilometers apart.
#
# - **Train 1**: Leaves Station A at 8:00 AM, traveling at 60 km/h towards Station B.
# - **Train 2**: Leaves Station B at 9:00 AM, traveling at 80 km/h towards Station A.
#
# We need to determine the time at which these two trains will meet each other.
#
# ### Visualizing the Scenario
#
# First, let's visualize the situation:
#
# - At 8:00 AM:
#   - Train 1 starts from Station A towards Station B at 60 km/h.
#   - Train 2 is still at Station B; it hasn't left yet.
#
# - From 8:00 AM to 9:00 AM (one hour):
#   - Train 1 is moving towards Station B.
#   - Train 2 is still at Station B.
#
# At 9:00 AM:
# - Train 1 has been traveling for 1 hour at 60 km/h, so it has covered:
#   - Distance = Speed × Time = 60 km/h × 1 h = 60 km.
#   - So, at 9:00 AM, Train 1 is 60 km away from Station A towards Station B.
#   - Therefore, the remaining distance between Train 1 and Station B is:
#     - Total distance - distance covered by Train 1 = 300 km - 60 km = 240 km.
#
# Now, at 9:00 AM:
# - Train 2 starts from Station B towards Station A at 80 km/h.
# - Train 1 is at the 60 km mark from Station A, moving towards Station B at 60 km/h.
# - The distance between the two trains at 9:00 AM is 240 km.
#
# ### Relative Speed Concept
#
# When two objects are moving towards each other, their relative speed is the sum of their individual speeds.
#
# - Speed of Train 1: 60 km/h
# - Speed of Train 2: 80 km/h
# - Relative speed when moving towards each other: 60 + 80 = 140 km/h
#
# This means that the distance between the two trains is decreasing at a rate of 140 km every hour.
#
# ### Calculating Time to Meet After 9:00 AM
#
# At 9:00 AM, the distance between the two trains is 240 km, and they're closing that distance at 140 km/h.
#
# Time taken to meet after 9:00 AM = Distance / Relative Speed
# = 240 km / 140 km/h
# = 24/14 hours
# = 12/7 hours
# ≈ 1.714 hours
#
# To convert 0.714 hours to minutes:
# 0.714 × 60 ≈ 42.857 minutes
#
# So, approximately 1 hour and 43 minutes after 9:00 AM.
#
# Adding that to 9:00 AM:
# 9:00 AM + 1 hour = 10:00 AM
# 10:00 AM + 43 minutes ≈ 10:43 AM
#
# But let's calculate it more precisely without approximating:
#
# 12/7 hours = 1 hour + (5/7) hours
# (5/7) hours = (5/7) × 60 minutes ≈ 42.857 minutes
#
# So, 1 hour and ~42.857 minutes after 9:00 AM is approximately 10:42:51 AM.
#
# However, since the speeds are given as whole numbers, it's likely that the exact time is a simple fraction. Let's see:
#
# 12/7 hours is exactly 1 hour and 42 + 6/7 minutes, which is 1 hour, 42 minutes, and about 51.428 seconds.
#
# But in practical terms, we can say they meet at approximately 10:43 AM.
#
# But let's check if we can express it exactly.
#
# ### Alternative Approach: Using Equations
#
# Let's define the time from 8:00 AM as 't' hours.
#
# - Train 1:
#   - Departs at t=0 (8:00 AM).
#   - Speed: 60 km/h.
#   - Distance covered by Train 1 at time t: D1 = 60t.
#
# - Train 2:
#   - Departs at t=1 (9:00 AM).
#   - Speed: 80 km/h.
#   - Distance covered by Train 2 at time t: D2 = 80(t - 1), for t ≥ 1.
#
# The sum of the distances covered by both trains when they meet should be equal to the total distance between the stations, which is 300 km.
#
# So, D1 + D2 = 300
# 60t + 80(t - 1) = 300
#
# Now, solve for t:
#
# 60t + 80t - 80 = 300
# 140t - 80 = 300
# 140t = 300 + 80
# 140t = 380
# t = 380 / 140
# t = 38 / 14
# t = 19 / 7 hours
#
# Now, convert 19/7 hours to hours and minutes:
#
# 19 ÷ 7 = 2 with a remainder of 5, so 2 and 5/7 hours.
#
# 5/7 hours = (5/7) × 60 ≈ 42.857 minutes.
#
# So, t = 2 hours and ~42.857 minutes after 8:00 AM.
#
# 8:00 AM + 2 hours = 10:00 AM
# 10:00 AM + ~42.857 minutes ≈ 10:42:51 AM.
#
# This matches our previous calculation.
#
# ### Verifying the Answer
#
# Let's verify by calculating the distances covered by each train at t = 19/7 hours.
#
# - Train 1:
#   - Distance = 60 × (19/7) = 1140 / 7 ≈ 162.857 km from Station A.
#
# - Train 2:
#   - Time traveled = t - 1 = 19/7 - 7/7 = 12/7 hours.
#   - Distance = 80 × (12/7) = 960 / 7 ≈ 137.143 km from Station B.
#
# Adding both distances: 162.857 + 137.143 ≈ 300 km, which matches the total distance between the stations.
#
# ### Conclusion
#
# The two trains will meet at approximately **10:42:51 AM**. However, since the problem likely expects an exact fraction, we can say they meet at **19/7 hours after 8:00 AM**, which is **2 hours and 5/7 hours after 8:00 AM**, or more precisely, **10:42 and 6/7 minutes AM**.
#
# But in practical terms, it's reasonable to say they meet at **10:43 AM**.
#
# However, looking back at the initial approach where we calculated the time after 9:00 AM as 12/7 hours, which is 1 hour and 5/7 hours, leading to 10:42:51 AM, seems consistent.
#
# Given that, the exact time is **19/7 hours after 8:00 AM**, which is **10:42:51 AM**.
#
# But since the options or the format might expect a simpler answer, and considering that 19/7 hours is approximately 2.714 hours, which is 2 hours and ~42.857 minutes, the most precise answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But in decimal terms, it's approximately 10:42:51 AM.
#
# Given that, and since the problem doesn't specify the format, the exact time is **19/7 hours after 8:00 AM**, which is **10:42:51 AM**.
#
# However, if we're to present it in a more conventional time format without fractions, we might say:
#
# **The two trains will meet at approximately 10:43 AM.**
#
# But to be precise, it's exactly at **10:42 and 6/7 minutes AM**.
#
# Given that, and considering that the initial calculation after 9:00 AM was 12/7 hours, which is 1 hour and 5/7 hours, leading to 10:42:51 AM, that seems correct.
#
# ### Final Answer
#
# After carefully working through the problem, the two trains will meet at **10:42 and 6/7 minutes AM**, or approximately **10:43 AM**.
#
# Expressed precisely:
#
# - **Time after 8:00 AM when they meet:** 19/7 hours (which is 2 hours and 5/7 hours).
# - **Converted to minutes:** 5/7 hours = 42 + 6/7 minutes.
# - **Therefore, they meet at:** 10:42 and 6/7 minutes AM.
#
# So, the exact time is **10:42 and 6/7 minutes AM**.
#
# In practical terms, this is approximately **10:43 AM**.
#
# But the precise answer is **10:42 and 6/7 minutes AM**.
#
# However, since the problem likely expects a time in hours and minutes without fractions, and given that 6/7 minutes is about 51.428 seconds, the closest conventional time is **10:43 AM**.
#
# But to be mathematically precise, it's **10:42 and 6/7 minutes AM**.
#
# Given that, and considering that the options might not have such precise times, the most accurate answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But if we're to choose the closest conventional time, it's **10:43 AM**.
#
# Given that, and since the initial calculation after 9:00 AM was 12/7 hours (1 hour and 5/7 hours), leading to 10:42:51 AM, the precise answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
#
# But in decimal terms, that's approximately 10:42:51 AM.
#
# Therefore, the exact time is **10:42 and 6/7 minutes AM**.
#
# ### Simplified Exact Answer
#
# To present it clearly:
#
# - **Total time from 8:00 AM until meeting:** 19/7 hours = 2 hours and 5/7 hours.
# - **5/7 hours = 42 + 6/7 minutes.**
# - **So, 8:00 AM + 2 hours = 10:00 AM.**
# - **Add 42 + 6/7 minutes to 10:00 AM: 10:42 and 6/7 minutes AM.**
#
# Thus, the two trains meet at **10:42 and 6/7 minutes AM**.
#
# ### Final Presentation
#
# After carefully working through the problem, the exact time at which the two trains meet is:
#
# **10:42 and 6/7 minutes AM.**
#
# This is approximately **10:43 AM**.
#
# But the precise answer is **10:42 and 6/7 minutes AM**.
#
# ### Step-by-Step Summary
#
# 1. **From 8:00 AM to 9:00 AM:**
#    - Only Train 1 is moving.
#    - Distance covered by Train 1: 60 km.
#    - Remaining distance between Train 1 and Station B: 300 - 60 = 240 km.
#
# 2. **At 9:00 AM:**
#    - Train 2 starts from Station B towards Station A.
#    - Distance between the two trains: 240 km.
#    - Relative speed towards each other: 60 + 80 = 140 km/h.
#
# 3. **Time to meet after 9:00 AM:**
#    - Time = Distance / Relative Speed = 240 / 140 = 12/7 hours = 1 hour and 5/7 hours.
#
# 4. **Adding to 9:00 AM:**
#    - 1 hour after 9:00 AM is 10:00 AM.
#    - 5/7 hours = 42 + 6/7 minutes.
#    - So, 10:00 AM + 42 + 6/7 minutes = 10:42 and 6/7 minutes AM.
#
# Therefore, the two trains meet at **10:42 and 6/7 minutes AM**.
#
# ### Verification
#
# Let's verify the distances:
#
# - **Train 1:**
#   - Total time from 8:00 AM: 19/7 hours.
#   - Distance: 60 * (19/7) = 1140/7 ≈ 162.857 km from Station A.
#
# - **Train 2:**
#   - Time from 9:00 AM: 12/7 hours.
#   - Distance: 80 * (12/7) = 960/7 ≈ 137.143 km from Station B.
#
# Total distance: 162.857 + 137.143 = 300 km, which matches the distance between the stations.
#
# Thus, the calculations are correct.
#
# ### Final Answer
#
# The two trains will meet at **10:42 and 6/7 minutes AM**.
#
# Expressed differently, this is **19/7 hours after 8:00 AM**, which is **2 hours and 5/7 hours after 8:00 AM**, leading to **10:42 and 6/7 minutes AM**.
#
# In decimal terms, this is approximately **10:42:51 AM**.
#
# Therefore, the precise time is **10:42 and 6/7 minutes AM**.
#
# If an exact fraction is acceptable, that's the answer. If a conventional time is preferred, it's approximately **10:43 AM**.
#
# Given that, the exact answer is:
#
# **The two trains will meet at 10:42 and 6/7 minutes AM.**
